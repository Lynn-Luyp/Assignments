# %% [markdown]
# # 段落

# %% [markdown]
# ## \命令行{参数}

# %% [markdown]
# ### \documentclass

# %% [markdown]
# \documentclass[UTF8]{文档类型}  # 如果这里文章中有中文的话一定要加上[UTF8]
# article, book, report, beamer(幻灯片), ctexart(中文)

# %% [markdown]
# ### \title{}

# %% [markdown]
# ### \author{}

# %% [markdown]
# ### \date{today}

# %% [markdown]
# ### \maketitle (正文区必须要有才可以显示上述内容)

# %% [markdown]
# ### \begin

# %% [markdown]
# ### \end

# %% [markdown]
# ## 格式化

# %% [markdown]
# ### 加粗

# %% [markdown]
# \textbf{}, bf是bold font缩写，代表粗体

# %% [markdown]
# ### 斜体

# %% [markdown]
# \textit{}, it是italic缩写，代表斜体

# %% [markdown]
# ### 下划线

# %% [markdown]
# \underline{}

# %% [markdown]
# ### 空格

# %% [markdown]
# 一个回车或者空格都可以

# %% [markdown]
# ### 新的段落

# %% [markdown]
# 两个回车

# %% [markdown]
# ## 段落布局

# %% [markdown]
# ### 章节 chapters and sections

# %% [markdown]
# \section{节的名字}
# 新的节

# %% [markdown]
# \subsection{子节的名字}
# 新的子节

# %% [markdown]
# \subsubsection{三级标题}
# 新的三级标题

# %% [markdown]
# \chapter{第几章}
# 这个需要是类型为书籍{ctexbook}才能用

# %% [markdown]
# \part{}
# 书籍中的第几部

# %% [markdown]
# 换行
# \\

# %% [markdown]
# ### 目录

# %% [markdown]
# \tableofcontents

# %% [markdown]
# ### 前言

# %% [markdown]
# \begin 之前的内容是前言

# %% [markdown]
# ### 图片

# %% [markdown]
# \usepackage{graphicx}

# %% [markdown]
# \graphicspath{{figures/}}
# 指定搜索路径

# %% [markdown]
# \includegraphics[width = 0.5\textwidth,angle = 45]{图片名}
# textwidth指图像的宽度

# %% [markdown]
# \centering 居中显示

# %% [markdown]
# \caption 标题

# %% [markdown]
# 图片环境
# \begin{figure}

# %% [markdown]
# \caption{\label{fig:frog}This frog was uploaded via the file-tree menu.}

# %% [markdown]
# 交叉引用
# \label{fig-lion}
# 引用：\ref{fig-lion}
# The picture of frog is seen in Figure \ref{fig-drog}
# \begin{figure}
#     \centering
#     \includegraphics[width = 0.3\textwidth]{frog.jpg}
#     \caption{This is the frog}
#     \label{fig-drog}
# \end{figure}

# %% [markdown]
# #### 图片并排排列

# %% [raw]
# \begin{figure}[htbp]
# \centering
# \begin{minipage}[t]{0.4\textwidth}
# \centering
# \includegraphics[width=\textwidth]{pc vs mobile.png}
# \caption{\label{fig:pc vs mobile}The recommended architecture.}
# \end{minipage}
# \hspace{0.5in}
# \begin{minipage}[t]{0.4\textwidth}
# \centering
# \includegraphics[width=\textwidth]{pc .png}
# \caption{\label{fig:pc}The recommended architecture.}
# \end{minipage}
# \end{figure}

# %% [markdown]
# ### 第一点第二点第三点

# %% [markdown]
# 无序环境
# \begin{itemize}
# \end{itemize}

# %% [markdown]
# 有序环境
# \begin{enumerate}
# \end{enumerate}

# %% [markdown]
# ### 公式

# %% [markdown]
# https://latex.codecogs.com/eqneditor/editor.php

# %% [raw]
# $E=mc2$ 是一行内的公式
# $$f(X) = 3x^2 + x - 10$$ 是另起一行的公式

# %% [markdown]
# $E=mc^2$

# %% [markdown]
# \ begin{equation}
# 单独写一行
# \ end{equation}

# %% [raw]
# 也可以用
# \[
# 内容
# \]

# %% [raw]
# $\frac{k\varphi(n)}{x}$

# %% [markdown]
# $\frac{k\varphi(n)}{x}$

# %% [markdown]
# ### 表格

# %% [markdown]
# \begin{tabular}
# \end{tabular}

# %% [raw]
# \begin{tabular}{|c|c|c|}  % 加上c|c 竖直边框
# \hline % 水平边框
# table1 & table2 & table3 \\
# \hline % 水平边框
# table4 & table5 & table6 \\
# \hline % 水平边框
# table7 & table8 & table9 \\
# \hline % 水平边框
#
# \end{tabular}
#
# 双横线 \hline\hline

# %% [markdown]
# 如果要加上边框的话，最后一行也要有\\和 \hline

# %% [markdown]
# 列宽|p{2cm}|

# %% [markdown]
# 格式编辑：
# \begin{table}
# \center
# tabular
# \caption{标题}
# \end{table}

# %% [markdown]
# ### 字体

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# \textrm 字体格式

# %% [markdown]
# \renewcommand{\rmdefault}{phv}
# \renewcommand{\sfdefault}{phv} % Arial

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 空白

# %% [markdown]
# a\quad b 一个缩进

# %% [markdown]
# ### 字符

# %% [markdown]
#  \$ \textbackslash

# %% [markdown]
# ### 页脚页码

# %% [raw]
# \begin{titlingpage}
# \maketitle
# \thispagestyle{empty}
# \end{titlingpage}
#
#
# \fancyhf{}
# \pagestyle{fancy}
# \fancyhead[C]{BDTV}
# \fancyfoot[C]{\thepage}

# %% [markdown]
# # Harvard引用

# %% [markdown]
# https://www.imperial.ac.uk/media/imperial-college/administration-and-support-services/library/public/LaTeX-example-Harvard-apr-2019.pdf

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
