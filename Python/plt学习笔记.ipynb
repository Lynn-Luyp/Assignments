# %% [markdown]
# # Matplotlib 学习笔记

# %%
# 输入库
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## figure

# %%
#画布
fig = plt.figure()

# %% [markdown]
# ## Axes

# %%
# Create Figure (empty canvas)
fig = plt.figure()

# Add set of axes to figure
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

# Plot on that set of axes
axes.plot([1, 2, 3, 4], [1, 4, 2, 3], 'r') # r is colour red

# %%
#画布上的物体
ax = fig.add_subplot(1,1,1)

# %%
ax1 = plt.axes()
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])
ax1.plot([1,2,3],[1,2,3])

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111, projection='3d')

# %% [markdown]
# ## Axis

# %%
# 轴

# %% [markdown]
# ## 保存图片

# %%
plt.savefig('')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-36b9878446fc> in <module>
# ----> 1 plt.savefig('')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## axvline

# %%
import matplotlib.pyplot as plt
plt.axvline(1)
plt.axvline(0.5,ymin=0,ymax = 0.5,color = 'black')
plt.axvline(1.5,ymin=0.5,ymax = 0.9,color = 'red')
plt.xlim([0,2])
# Out:
# (0.0, 2.0)

# %% [markdown]
# ## axvspan

# %%
fig,ax = plt.subplots()
x = np.linspace(0,10,100)
ax.plot(x,np.sin(x),'--')
ax.set_ylim([-1,1])
ax.set_xlabel('variable x')
ax.set_ylabel('value y')
ax.set_title('三角函数',font='Microsoft YaHei')
ax.axhline(0.8,c = 'black',ls = '-.')
ax.grid()
ax.axvspan(4,6,facecolor='red',alpha = 0.3)
ax.axhspan(-0.2,0.2,facecolor='yellow',alpha = 0.3)

# %% [markdown]
# ## annotate

# %%
fig,ax = plt.subplots()
x = np.linspace(0,10,100)
ax.plot(x,np.sin(x),'--')
ax.set_ylim([-1,1])
ax.set_xlabel('variable x')
ax.set_ylabel('value y')
ax.set_title('三角函数',font='Microsoft YaHei')
ax.axhline(0.8,c = 'black',ls = '-.')
ax.grid()
ax.axvspan(4,6,facecolor='red',alpha = 0.3)
ax.axhspan(-0.2,0.2,facecolor='yellow',alpha = 0.3)
ax.text(3.2,0,'$sin(x)$')
ax.annotate('peak',xytext = (3.2,0.6),xy = (np.pi/2,1),fontsize = 16,arrowprops=dict(arrowstyle="->"))
ax.set_ylim([-1.5,1.5])
# Out:
# (-1.5, 1.5)

# %% [markdown]
# ## setp

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-2*np.pi, 2 * np.pi, 200)
y = np.sin(x)

line1,=plt.plot(x,y)

plt.setp(line1,ls='--')

plt.show()

# %% [markdown]
# 设置对象的属性

# %% [markdown]
# ## 线形

# %% [markdown]
# linewidth, linestyle, marker, mearkersize

# %%
# set the colour and line style and line width
x = pd.Series([1,2,3,4])
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green")

# %% [markdown]
# ## 调整子图位置/tight_layout

# %% [markdown]
# tight_layout

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot([1, 2, 3, 4], [1, 4, 2, 3], 'g')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')

# fig # Display the figure object  
plt.tight_layout() # avoid overlapping content

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot([1, 2, 3, 4], [1, 4, 2, 3], 'g')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')

# fig # Display the figure object  
# plt.tight_layout() # avoid overlapping content

# %% [markdown]
# ## 获得像素值

# %% [markdown]
# img.getpixel，获得该点的像素值

# %% [markdown]
# putpixel 输出成图像点

# %% [markdown]
# ## subplots_adjust

# %% [markdown]
# plt.subplots_adjust(0.01, 0.05, 0.99, 0.94, 0.04, 0.)

# %% [markdown]
# 调整最终的图与边缘的距离

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 回归

# %%
import numpy as np 
import matplotlib.pyplot as plt
from scipy.stats import linregress

def gen_football_team(n_players, mean_shoe, mean_jersey):
    shoe_sizes = np.random.normal(size=n_players, loc=mean_shoe, scale=.15 * mean_shoe)
    jersey_sizes = mean_jersey / mean_shoe * shoe_sizes + np.random.normal(size=n_players, scale=.05 * mean_jersey)

    return shoe_sizes, jersey_sizes

shoes, jerseys = gen_football_team(16, 11, 100)

fig = plt.figure(figsize=(12, 6))
fig.suptitle('Football team equipment profile')

ax1 = plt.subplot(221)
ax1.hist(shoes)
ax1.set_xlabel('Shoe size')
ax1.set_ylabel('Counts')

ax2 = plt.subplot(223)
ax2.hist(jerseys)
ax2.set_xlabel('Chest size (cm)')
ax2.set_ylabel('Counts')

ax3 = plt.subplot(122)
ax3.scatter(shoes, jerseys, label='Data')
ax3.set_xlabel('Shoe size')
ax3.set_ylabel('Chest size (cm)')

fit_line = linregress(shoes, jerseys)
ax3.plot(shoes, fit_line[1] + fit_line[0] * shoes, 'r', label='Line of best fit')

# handles, labels = ax3.get_legend_handles_labels()
# ax3.legend(handles[::-1], labels[::-1]);
ax3.legend()

# %%
labels
# Out:
# ['Line of best fit', 'Data']

# %% [markdown]
# ## data作图

# %%
import pandas as pd
happiness = pd.read_csv('https://raw.githubusercontent.com/Sophia-Zheng/data/main/Happiness%20report-2015.csv')
happiness.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
happiness.columns = happiness.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
happiness.head()
# Out:
# <ipython-input-27-5f81bfd3accb>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   happiness.columns = happiness.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
#        country          region  happiness_rank  happiness_score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    standard_error  economy_gdp_per_capita   family  health_life_expectancy  \
# 0         0.03411                 1.39651  1.34951                 0.94143
# ...

# %% [markdown]
# ### scatter

# %%
happiness.plot.scatter(x="happiness_score",y="economy_gdp_per_capita",c= "happiness_score", cmap='coolwarm',title='Happiness')
# Out:
# <AxesSubplot:title={'center':'Happiness'}, xlabel='happiness_score', ylabel='economy_gdp_per_capita'>

# %% [markdown]
# ### hist

# %%
happiness["happiness_score"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df = happiness.drop(['country','region','happiness_rank','happiness_score','standard_error'],axis=1)
df.plot.hist(subplots=True, layout=(2,4), figsize=(20, 10))
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>]], dtype=object)

# %% [markdown]
# ### bar

# %%
data = happiness.groupby('region', as_index=True).agg({"happiness_score": "mean"}).sort_values(by='happiness_score')

data.plot.bar()
# Out:
# <AxesSubplot:xlabel='region'>

# %%
data.plot.barh()
# Out:
# <AxesSubplot:ylabel='region'>

# %%
data.plot(kind='barh',color='red',xlim=(0,8),figsize=(5,5),legend=False,title='Happiness report')
# Out:
# <AxesSubplot:title={'center':'Happiness report'}, ylabel='region'>

# %% [markdown]
# ## 子图/多图

# %% [markdown]
# subplot 是表示2个子图大小一样
# axes可以弄2个子图大小不一样的图

# %% [markdown]
# ### 大小不同的子图

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.65, 0.7, 0.1, 0.1]) # inset axes

# Larger Figure Axes 1
axes1.plot([1, 2, 3, 4], [1, 4, 2, 3], 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title')

# Insert Figure Axes 2
axes2.plot([1, 4, 2, 3],[1, 2, 3, 4], 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title')
# Out:
# Text(0.5, 1.0, 'Axes 2 Title')

# %% [markdown]
# ### 子图

# %% [markdown]
# #### seaborn

# %%
def plot_corr(df):
    corr = df.corr()
    fig,ax = plt.subplots(figsize = (12,10))
    cmap = sns.diverging_palette(220, 10, as_cmap=True)   
    fig = sns.heatmap(corr, square= True, ax = ax,cmap = cmap,annot = True, 
        annot_kws = { 'fontsize' : 10 })

# %%
df = pd.DataFrame({'a':[1,25,3],'b':[34,5,6],'c':[7,8,9]})
plot_corr(df)

# %% [markdown]
# #### subplots()

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots(5,4,figsize = (10,10))
ax[0][1].plot([1, 2, 3, 4], [1, 4, 2, 3], 'g')

# %%
fig,ax = plt.subplots(1,3,figsize = (5,2))
for i in range(3):
    ax[i].plot([1, 2, 3, 4], [1, 4, 2, 3], 'g')

# %%
fig,ax = plt.subplots(3,1,figsize = (10,10))
ax[0].plot([1, 2, 3, 4], [1, 4, 2, 3], 'g')
ax[0].set_title('figure 1')
ax[1].plot([1, 2, 3, 4], [1, 4, 2, 3], 'g')
ax[2].plot([1, 2, 3, 4], [1, 4, 2, 3], 'g')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2) # In case you can fill different data for each axe

ax1.plot([1, 2, 3, 4], [1, 4, 2, 3], 'g')
ax1.set_title('title_1')
ax2.plot([1, 4, 2, 3],[1, 2, 3, 4],'r')
ax2.set_title('title_2')

fig # Display the figure object 
plt.tight_layout() # avoid overlapping content

# %% [markdown]
# #### add_subplot()

# %%
x = np.array([1,2,3,4])
fig = plt.figure(figsize=(12,5))
ax1 = fig.add_subplot(141)
ax1.plot(x,x)
ax1 = fig.add_subplot(142)
ax1.plot(x,x**2)
ax1 = fig.add_subplot(143)
ax1.plot(x,x**3)
ax1 = fig.add_subplot(144)
ax1.plot(x,x**4)

# %% [markdown]
# ### 网格子图

# %%
fig, axes = plt.subplots(4, 10, figsize=(10, 4),
							 subplot_kw={'xticks':[], 'yticks':[]},
							 gridspec_kw=dict(hspace=0.1, wspace=0.1))

# %% [markdown]
# ### 子图共坐标

# %%
fig,ax = plt.subplots(2,3,sharex = True,sharey = True)
ax[0,0].plot(x,np.sin(x),label = 'sin')
ax[0,1].plot(x,2*np.sin(x),label = 'sin')
ax[0,2].plot(x,4*np.cos(x),label = 'cos')
ax[0,0].set_ylim([-6,6])
# Out:
# (-6.0, 6.0)

# %% [markdown]
# ### 大小不一样的子图

# %%
grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)
plt.subplot(grid[0, 0])
plt.subplot(grid[0, 1:])
plt.subplot(grid[1, :2])
plt.subplot(grid[1, 2]);

# %% [markdown]
# ## 三维图

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111, projection='3d')

# %%
from mpl_toolkits import mplot3d
ax = plt.axes(projection = '3d')
z = np.linspace(0,20,1000)
y = np.sin(z)
x = np.cos(z)
ax.plot3D(x,y,z)

# %%
from mpl_toolkits import mplot3d
ax = plt.axes(projection = '3d')
z = np.random.randn(100)
y = 5*np.random.rand(100)
x = 10*np.random.rand(100)
ax.scatter3D(x,y,z)

# %% [markdown]
# ## legend

# %% [markdown]
# ### 位置，去边框

# %%
x = np.linspace(0,np.pi*3)
fig,ax = plt.subplots()
ax.plot(x,np.sin(x),'g-.',label = 'sin(x)')
ax.plot(x,np.cos(x),'r--',label = 'cos(x)')
ax.legend(loc = 1,frameon = False)

# %% [markdown]
# **frameon**:
#     legend 边框
#
# **loc**:
#     best
#     upper right
#     upper left
#     lower left
#     lower right
#     right
#     center left
#     center right
#     lower center
#     upper center
#     center
#
# **ncol**:
#     列

# %% [markdown]
# ### 分两列

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0,np.pi*3)
fig,ax = plt.subplots()
ax.plot(x,np.sin(x),'g-.',label = 'sin(x)')
ax.plot(x,np.cos(x),'r--',label = 'cos(x)')
ax.legend(loc='lower center',frameon = False,ncol = 2)

# %% [markdown]
# ### 2个legend

# %%
lines = []
x = np.linspace(0,np.pi*3)
fig,ax = plt.subplots()
lines += ax.plot(x,np.sin(x),'g')
lines += ax.plot(x,np.sin(x+np.pi/2),'r')
lines += ax.plot(x,np.sin(x+np.pi),'y')
lines += ax.plot(x,np.sin(x+np.pi*3/2),'k')
ax.legend(lines[:2],['first','second'],loc='upper right',frameon = True)
from matplotlib.legend import Legend
leg = Legend(ax,lines[2:],['third','fourth'],loc='lower right',frameon = True)
ax.add_artist(leg)

# %% [markdown]
# ### legend 汉字

# %%
legend_font = {"family" : "Microsoft YaHei"}
plt.legend((u'头等舱', u'2等舱',u'3等舱'),loc='best',prop = legend_font) # sets our legend for our graph.

# %% [markdown]
# ## 汉字字体

# %% [markdown]
# Python常用中文字体对应名称
# 黑体 SimHei
# 微软雅黑 Microsoft YaHei
# 微软正黑体 Microsoft JhengHei
# 新宋体 NSimSun
# 新细明体 PMingLiU
# 细明体 MingLiU
# 标楷体 DFKai-SB
# 仿宋 FangSong
# 楷体 KaiTi
# 仿宋_GB2312 FangSong_GB2312
# 楷体_GB2312 KaiTi_GB2312

# %% [markdown]
# ## 横坐标刻度标注

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Online_Retail/Online_Retail.csv'
df = pd.read_csv(url, encoding = 'latin1')
result = df[df.Country != 'United Kingdom'].groupby('Country').Quantity.sum().sort_values(ascending = False)
fig,ax = plt.subplots(figsize = (10,5))
ax.bar(np.arange(10),result[:10])
ax.set_xticks(np.arange(10))
ax.set_xticklabels(result[:10].index)
# Out:
# [Text(0, 0, 'Netherlands'),
#  Text(1, 0, 'EIRE'),
#  Text(2, 0, 'Germany'),
#  Text(3, 0, 'France'),
#  Text(4, 0, 'Australia'),
#  Text(5, 0, 'Sweden'),
#  Text(6, 0, 'Switzerland'),
#  Text(7, 0, 'Spain'),
#  Text(8, 0, 'Japan'),
#  Text(9, 0, 'Belgium')]

# %%
result[:10].plot(kind = 'bar',figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='Country'>

# %% [markdown]
# ## 设置图片单位为英寸

# %% [markdown]
# fig,ax = plt.subplots()
# ax.plot(df['Adj Close'])
# fig.set_size_inches(13.5, 9)

# %% [markdown]
# ## 直方图

# %% [markdown]
# ### fig,ax 方法

# %%
fig,ax = plt.subplots(3,1,figsize = (8,6))
ax[0].hist(tips_data.total_bill,bins = 14)
ax[0].set_title('Histgrame of total_bill')
ax[1].hist(tips_data.tip,bins = 20)
ax[2].hist(tips_data.total_bill)
ax[2].hist(tips_data.tip)
# Out:
# (array([41., 79., 66., 27., 19.,  5.,  4.,  1.,  1.,  1.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### df.plot方法

# %%
tips_data.tip.plot(kind = 'hist',bins = 10,density = True,label='bin')
tips_data.tip.plot(kind = 'kde',color='red',label='kde')
plt.legend()

# %% [markdown]
# ### sns.distplot方法

# %%
sns.distplot(tips_data.tip,bins = 10,kde = True)
# Out:
# /opt/conda/envs/python2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### sns.histplot方法

# %%
import seaborn as sns
x=np.random.randn(1000)
sns.histplot(data = x,bins = 10,kde = False,stat = 'count')
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# stat{“计数”，“频率”，“密度”，“概率”}
# 要在每个箱子中计算的聚合统计信息。
#
# count 显示观察次数
# frequency 显示观察数除以箱子宽度
# density 规格化计数，使直方图的面积为1
# probability 规格化计数，使条形高度之和为1

# %% [markdown]
# ## 箱线图

# %% [markdown]
# ### fig,ax方法

# %%
fig,ax = plt.subplots()
ax.boxplot(tips_data.total_bill,vert=False)
ax.set_title('boxplot')
# Out:
# Text(0.5,1,'boxplot')

# %% [markdown]
# ### df.plot方法

# %%
tips_data.total_bill.plot(kind='box',vert = False)

# %% [markdown]
# ### sns.boxplot方法

# %%
# Create a boxplot of the total bill amounts
sns.boxplot(tips_data["total_bill"]).set_title("Box plot of the Total Bill")
plt.show()

# %% [markdown]
# ### 多组箱线图

# %%
# Create a boxplot of the tips and total bill amounts - do not do it like this
sns.boxplot(x = tips_data['day'],y= tips_data['tip'])
# sns.boxplot(x = tips_data["tip"]).set_title("Box plot of the Total Bill and Tips")
plt.show()

# %%
plt.boxplot((tips_data['tip'],tips_data['total_bill']))
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f647fdd7e10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f647fdec690>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f647fc84210>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f647fdece10>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f647fdd7ed0>,
# ...
#   <matplotlib.lines.Line2D at 0x7f647fc84d50>]}

# %%
sns.boxplot(data = da.loc[:,['BPXSY1','BPXSY2','BPXDI1','BPXDI2']])

# %% [markdown]
# ## 饼图

# %%
fig,ax = plt.subplots(figsize = (20,10))
df.Name.value_counts().plot.pie(autopct='%1.1f%%')
plt.legend()

# %% [markdown]
# ## 数据分段

# %%
da["agegrp"] = pd.cut(da.RIDAGEYR, [18, 30, 40, 50, 60, 70, 80]) # Create age strata based on these cut points
plt.figure(figsize=(12, 5))  # Make the figure wider than default (12cm wide by 5cm tall)
sns.boxplot(x="agegrp", y="BPXSY1", data=da)  # Make boxplot of BPXSY1 stratified by age group

# %%
da["agegrp"] = pd.cut(da.RIDAGEYR, [18, 30, 40, 50, 60, 70, 80])
plt.figure(figsize=(12, 5))
sns.boxplot(x="agegrp", y="BPXSY1", hue="RIAGENDRx", data=da)

# %% [markdown]
# ## 误差条

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,10,20)
y = 3*np.random.rand(20)
yerr = 0.8
fig,ax = plt.subplots()
ax.errorbar(x,y,yerr,fmt='.k')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## 条形图

# %% [markdown]
# ### 横向条形图

# %%
x = np.arange(12)
y = np.random.randint(0,10,len(x))
label = ['A','B','C','D','E','F','G','H','J','K','L','M']
fig,ax = plt.subplots()
ax.barh(x,y)
ax.set_yticks(x)
ax.set_yticklabels(label[::-1])
# Out:
# [Text(0, 0, 'M'),
#  Text(0, 1, 'L'),
#  Text(0, 2, 'K'),
#  Text(0, 3, 'J'),
#  Text(0, 4, 'H'),
#  Text(0, 5, 'G'),
#  Text(0, 6, 'F'),
#  Text(0, 7, 'E'),
#  Text(0, 8, 'D'),
#  Text(0, 9, 'C'),
#  Text(0, 10, 'B'),
#  Text(0, 11, 'A')]

# %% [markdown]
# ### 堆积条形图

# %%
df = pd.DataFrame({'Name':['Bulbasaur','Ivysaur','Venusaur','VenusaurMega','Charmander']
                   ,'Defense':[49,63,83,123,43]
                   ,'Attack':[49,62,82,100,52]
                   ,'Hp':[45,60,80,80,39]})
x = [1,2,3,4,5]
fig,ax = plt.subplots()
ax.bar(x,df.Hp,label='Hp',color = 'red')
ax.bar(x,df.Attack,label='Attack',bottom = df.Hp,color = 'orange')
ax.bar(x,df.Defense,label='Defense',color = 'blue',bottom = df.Hp+df.Attack)
ax.legend(loc = 'upper right')
ax.set_xlabel('Pokemon')
ax.set_ylabel('Value')
ax.set_xticks(x)
ax.set_xticklabels(df.Name)
ax.set_title('5 Pokemon Defense & Attack & Hp')
# Out:
# Text(0.5, 1.0, '5 Pokemon Defense & Attack & Hp')

# %% [markdown]
# ### 2列条形图

# %%
x = [1,2,3,4,5]
width = 0.3
fig,ax = plt.subplots()
ax.bar([_-0.15 for _ in x],df.Hp,label = 'Hp',width = width)
ax.bar([_+0.15 for _ in x],df.Attack,label = 'Attack',width = width)
ax.set_xticks(x)
ax.set_xticklabels(df.Name)
ax.legend()
ax.set_title('Pokemon Hp & Attack')
# Out:
# Text(0.5, 1.0, 'Pokemon Hp & Attack')

# %% [markdown]
# ## 堆积折线图

# %%
fig,ax = plt.subplots()
ax.stackplot(x,df.Defense,df.Attack,df.Hp)
ax.legend(labels = ['Defense','Attack','Hp'],loc = 'upper left')
ax.set_xticks(x)
ax.set_xticklabels(df.Name)
# Out:
# [Text(1, 0, 'Bulbasaur'),
#  Text(2, 0, 'Ivysaur'),
#  Text(3, 0, 'Venusaur'),
#  Text(4, 0, 'VenusaurMega'),
#  Text(5, 0, 'Charmander')]

# %% [markdown]
# ## 二维直方图

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T
plt.hist2d(x, y, bins=30);

# %% [markdown]
# ## 六角形直方图

# %%
plt.hexbin(x, y, gridsize=30);

# %% [markdown]
# ## 色阶图

# %%
x = np.linspace(0, 10, 1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])

plt.imshow(I)
plt.colorbar();

# %%
fig,ax = plt.subplots()
x = df.Attack
y = df.Defense
colors = df.Hp
plt.scatter(x,y,c = colors,alpha = 0.5)
plt.colorbar()

# %% [markdown]
# ## 散点图+频度分布图

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.scatter(x, y,s=3,alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal')
y_hist.invert_xaxis()

# %% [markdown]
# # seaborn 学习笔记

# %% [markdown]
# x相当于分组的label，y相当于value
# seaborn的第一个参数默认为x，如果想要实现分组的时候令data = df.loc[:,['a','b']] 可以实现分组

# %%
import seaborn as sns
# %matplotlib inline
# Load an example dataset
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## boxplot 箱线图

# %%
sns.boxplot(data = da.loc[:,['BPXSY1','BPXSY2','BPXDI1','BPXDI2']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-1c24edbd4dc9> in <module>
# ----> 1 sns.boxplot(data = da.loc[:,['BPXSY1','BPXSY2','BPXDI1','BPXDI2']])
#
# NameError: name 'da' is not defined

# %%
# Create a boxplot and histogram of the tips grouped by smoking status
sns.boxplot(x = tips["tip"], y = tips["smoker"])
plt.show()

# %%
sns.boxplot(data=tips)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## distolot 直方图(将被废除，改为displot)

# %%
# Make a histogram of our 'bp' data using the seaborn library we imported as 'sns'
import seaborn as sns
sns.distplot(tips['total_bill'])
# Out:
# F:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],kde=False,bins=30)
# Out:
# F:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.histplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
# 根据hue(色相)来分组 
sns.displot(tips,x='total_bill',hue='sex')

# %%
sns.displot(tips,x='total_bill',col='sex',multiple='dodge')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(tips,x = 'total_bill',hue = 'smoker', col = 'sex')

# %%
sns.displot(tips,x='total_bill',hue='sex',kind='kde',multiple='stack')

# %%
sns.displot(tips,x='total_bill',y='tip',cbar=True)

# %% [markdown]
# ## scatterplot

# %%
# import the data generator
from sklearn.datasets import make_blobs

# create a dataset. X is a set of values to cluster; Y is the cluster they belong to
X, y = make_blobs(n_samples=100, n_features=2, centers=2)

# visualise the data in Matplotlib
import matplotlib.pyplot as plt
plt.scatter(X[:, 0], X[:, 1], color = 'g') 
plt.show()

# %%
# min-max scale the X data so it takes values between zero (min value) and one (max value)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(X) # transform the data

# import and fit the clustering algorithm
from sklearn.cluster import KMeans
clustering = KMeans(n_clusters=2).fit(X)

# add the data and the assigned cluster labels to a Pandas dataframe
import pandas as pd
df = pd.DataFrame(data={'x1': X[:, 0], 'x2': X[:, 1], 'label': clustering.labels_})  

# visualise the data using Seaborn
import seaborn as sns
sns.scatterplot(data=df, x='x1', y='x2', hue=df.label.to_list()) # note: we use the “to_list()” function to fix the labels to hue
# hue是分组信息
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %% [markdown]
# ## kdeplot

# %%
sns.kdeplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ## regplot 拟合回归图

# %%
sns.regplot(x="BMXLEG", y="BMXARML", data=da, fit_reg=False, scatter_kws={"alpha": 0.2})

# %% [markdown]
# ## jointplot 相关性作图

# %%
#ignore deprecation warning message
sns.jointplot(x="BMXLEG", y="BMXARML", kind='kde', data=da).annotate(stats.pearsonr)
# Out:
# /opt/conda/lib/python3.6/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
# joint distribution
sns.jointplot(data=tips,x='total_bill',y='tip',kind='hex')

# %% [markdown]
# ## relplot 相关性

# %%
# style是点或者×
# hue是色相，相当于区分颜色
sns.relplot(data=tips, x="total_bill", y="tip",hue='smoker',style='smoker')

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker",col="day", row='time',data=tips)

# %% [markdown]
# ## sns.violinplot 小提琴图

# %%
plt.figure(figsize=(12, 4))
a = sns.violinplot(da.DMDMARTLx, da.RIDAGEYR)

# %% [markdown]
# ## regplot 回归

# %% [markdown]
# 回归作图

# %%
sns.regplot(x="total_bill", y="tip", data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x="total_bill", y="tip", data=tips)

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", col="time", data=tips)

# %% [markdown]
# ## barplot 柱形图

# %%
# Make a Seaborn barplot with x = glasses and y = cartwheel distance
sns.barplot(x='Glasses',y='CWDistance',data=df,hue='Gender')

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.median)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex',y='total_bill',data=tips,ci=None)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex',y='total_bill',data=tips,ci='sd')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ci:float或者"sd"或None
# 在估计值附近绘制置信区间的大小，如果是"sd"，
# 则跳过bootstrapping并绘制观察的标准差，
# 如果为None,则不执行bootstrapping,并且不绘制错误条。

# %%
sns.barplot(x='day',y='total_bill',data=tips,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
ax = sns.barplot(x='day',y='total_bill',data=tips,hue='sex',dodge=False,ci=None)
ax.legend(loc=2)

# %% [markdown]
# ## stripplot 分布散点图

# %%
# strip plot
sns.stripplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# strip plot
sns.stripplot(x="day", y="total_bill", data=tips,jitter=False)
#The jitter parameter controls the magnitude of jitter or disables it altogether. The default is True.
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## countplot 计数

# %%
# count plot
sns.countplot(x='day',data=tips,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %% [markdown]
# ## Facetgrid

# %% [markdown]
# 生成网格

# %%
g = sns.FacetGrid(tips, col="time", row="smoker") # create the gird first
g.map(sns.histplot, "total_bill") # map the plots

# %%
def plot_distribution( df , var , target , **kwargs ):
    row = kwargs.get( 'row' , None )
    col = kwargs.get( 'col' , None )
    facet = sns.FacetGrid( df , hue=target , aspect=4 , row = row , col = col ) # hue 色调，区分颜色不同
    facet.map( sns.kdeplot , var , shade= True ) # var 是轴的坐标
    facet.set( xlim=( 0 , df[ var ].max() ) )
    facet.add_legend()

# %%
def plot_categories( df , cat , target , **kwargs ):
    row = kwargs.get( 'row' , None )
    col = kwargs.get( 'col' , None )
    facet = sns.FacetGrid( df , row = row , col = col )
    facet.map( sns.barplot , cat , target ) 
    facet.add_legend()

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv(r'C:\Users\Perry_Lu\Desktop\ML\ML projects\titanic\train.csv')
plot_distribution( df , var = 'Age' , target = 'Survived' , row = 'Sex' ) # Sex 有2个选项，所有有2行

# %%
plot_categories( df , cat = 'Embarked' , target = 'Survived' )
# Out:
# F:\Anaconda\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ## catplot

# %%
# swarm plot
sns.catplot(x="day", y="total_bill", data=tips,kind='violin') 
#  kind 的类型有 strip, swarm, box, violin,boxen,point, bar, count. strip是默认值

# %% [markdown]
# ## heatmap 热力图

# %% [markdown]
# cmap 的制作：seaborn.diverging_palette(as_cmap = True)

# %%
import pandas as pd
happiness = pd.read_csv('https://raw.githubusercontent.com/Sophia-Zheng/data/main/Happiness%20report-2015.csv')
happiness.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
happiness.columns = happiness.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
happiness.head()
# Out:
# <ipython-input-24-5f81bfd3accb>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   happiness.columns = happiness.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
#        country          region  happiness_rank  happiness_score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    standard_error  economy_gdp_per_capita   family  health_life_expectancy  \
# 0         0.03411                 1.39651  1.34951                 0.94143
# ...

# %%
happiness.plot.scatter(x="happiness_score",y="economy_gdp_per_capita",c= "happiness_score", cmap='coolwarm',title='Happiness')
# Out:
# <AxesSubplot:title={'center':'Happiness'}, xlabel='happiness_score', ylabel='economy_gdp_per_capita'>

# %% [markdown]
# sns.heatmap

# %%
# heatmap
tips.corr() # Matrix form for correlation data
sns.heatmap(tips.corr()) # visualise the heatmap based on the correlation matrix
# Out:
# <AxesSubplot:>

# %%
# set annotation and colour map
sns.heatmap(tips.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## imshow

# %%
plt.imshow(comp.reshape(image_shape), cmap=plt.cm.gray,
                   interpolation='nearest', vmin=-vmax, vmax=vmax)

# %% [markdown]
# 将数据点显示成图像

# %% [markdown]
# nearest 表示距离近的用一种颜色来表示

# %%
from matplotlib import pyplot as plt  
  
X = [[0, 0.25], [0.5, 0.75]]   
 
fig = plt.figure()
ax = fig.add_subplot(121)
im = ax.imshow(X, cmap=plt.get_cmap('hot'))
plt.colorbar(im, shrink=0.5)
 
ax = fig.add_subplot(122)
im = ax.imshow(X, cmap=plt.get_cmap('hot'), interpolation='nearest',
               vmin=0, vmax=1) 
plt.colorbar(im, shrink=0.2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# coding=utf-8
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm 
from matplotlib import axes
 
def draw_heatmap(data,xlabels,ylabels):
    #cmap=cm.Blues    
    cmap=cm.get_cmap('rainbow',1000)
    figure=plt.figure(facecolor='w')
    ax=figure.add_subplot(1,1,1,position=[0.1,0.15,0.8,0.8])
    ax.set_yticks(range(len(ylabels)))
    ax.set_yticklabels(ylabels)
    ax.set_xticks(range(len(xlabels)))
    ax.set_xticklabels(xlabels)
    vmax=data[0][0]
    vmin=data[0][0]
    for i in data:
        for j in i:
            if j>vmax:
                vmax=j
            if j<vmin:
                vmin=j
    map=ax.imshow(data,interpolation='nearest',cmap=cmap,aspect='auto',vmin=vmin,vmax=vmax)
    cb=plt.colorbar(mappable=map,cax=None,ax=None,shrink=0.5)
    plt.show()
            
a=np.random.rand(10,10)
print (a)
xlabels=['A','B','C','D','E','F','G','H','I','J']
ylabels=['a','b','c','d','e','f','g','h','i','j']
draw_heatmap(a,xlabels,ylabels)
# Out:
# [[0.4484534  0.17168773 0.59952849 0.5832869  0.46205679 0.7607045
#   0.6221932  0.33698396 0.7454791  0.59998931]
#  [0.93967732 0.5875111  0.97480315 0.01939721 0.50011694 0.90251002
#   0.07932688 0.37703064 0.97419644 0.37989091]
#  [0.89260242 0.10722145 0.89517021 0.86936612 0.79461982 0.9754781
#   0.4920556  0.49921926 0.47813502 0.73314663]
#  [0.54055822 0.50789029 0.08089846 0.8229212  0.53796748 0.5091299
#   0.12131562 0.09608931 0.40805644 0.78634084]
#  [0.9993939  0.24346946 0.11448069 0.05294101 0.40538664 0.29454079
#   0.66762365 0.63529798 0.10500143 0.14350822]
#  [0.73427349 0.82352276 0.88893933 0.99038562 0.48375552 0.54470948
#   0.0414739  0.65074678 0.21283645 0.82552205]
#  [0.97124243 0.67556291 0.6642949  0.71461526 0.07214804 0.09168557
#   0.64893341 0.29513624 0.90129491 0.45323405]
#  [0.14224724 0.09362387 0.51227617 0.19929186 0.94254823 0.08980307
#   0.10054515 0.59221246 0.28010537 0.82140371]
# ...

# %% [markdown]
# # 实例

# %% [markdown]
# ## example1

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
A = np.arange(1,5)
B = A**2
C = A**3

# %%
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(A,B)
ax.plot(B,A)
ax.set_title('Title',fontsize=18)
ax.set_xlabel('xlabel', fontsize=18,fontfamily = 'sans-serif',fontstyle='italic')
ax.set_ylabel('ylabel', fontsize='x-large',fontstyle='oblique')
ax.legend()
ax.set_aspect('equal') 
ax.minorticks_on() 
ax.set_xlim(0,16) 
ax.grid(which='minor', axis='both')
ax.xaxis.set_tick_params(rotation=45,labelsize=18,colors='w') 
start, end = ax.get_xlim() 
ax.xaxis.set_ticks(np.arange(start, end,1)) 
ax.yaxis.tick_right()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# 这里的fig指的是画布，ax指的是图，这里只有一个图
# 看一下ax的属性

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
ax[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-b9c478fc82b3> in <module>
# ----> 1 ax[0]
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %% [markdown]
# ## example2

# %%
A = np.arange(1,5)
B = A**2
C = A**3

# %%
fig, ax = plt.subplots(2,2,figsize = (20,10))
ax[0,0].plot(A,B)
ax[0,0].plot(A,B+A**2)
ax[0,1].plot(A,C)
ax[1,0].plot(B,A)
ax[1,1].plot(B,C)
ax[0,0].legend(['a','b'],fontsize = 14)

# %%
ax.shape
# Out:
# (2, 2)

# %%
ax[0,1].plot(1,1)

# %% [markdown]
# ## example3

# %% [markdown]
# 参考链接：https://www.datacamp.com/community/blog/python-matplotlib-cheat-sheet#gs.uEKySpY

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [10,20,25,30]
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, y, color='b', linewidth=3)
ax.set_xlim([0,5])
ax.set_title(r'$sigma_i=15$',fontsize=20)
# Out:
# Text(0.5, 1.0, '$sigma_i=15$')

# %%
fig,ax = plt.subplots()
ax.plot(x,y,'r--')
plt.legend(['line'])
ax.scatter(x,y,color = 'k')

# %% [markdown]
# ## example4

# %%
#d slopping line. A rho of 0 will 
# get us a 'cloud' of points
r = 1

# Don't worry so much about the following three lines of code for now
# this is just getting the data for us to plot
mean = [15, 5]
cov = [[1, r], [r, 1]]
x, y = x, y = np.random.multivariate_normal(mean, cov, 400).T

# Adjust the figure size
plt.figure(figsize=(10,5))

# Plot the histograms of X and Y next to each other
plt.subplot(1,2,1)
plt.hist(x = x, bins = 15)
plt.title("X")

plt.subplot(1,2,2)
plt.hist(x = y, bins = 15)
plt.title("Y")

plt.show()

# %%
# Plot the data
plt.figure(figsize=(10,10))
plt.subplot(2,2,2)
plt.scatter(x = x, y = y)
plt.title("Joint Distribution of X and Y")

# Plot the Marginal X Distribution
plt.subplot(2,2,4)
plt.hist(x = x, bins = 15)
plt.title("Marginal Distribution of X")


# Plot the Marginal Y Distribution
plt.subplot(2,2,1)
plt.hist(x = y, orientation = "horizontal", bins = 15)
plt.title("Marginal Distribution of Y")

# Show the plots
plt.show()

# %% [markdown]
# ## example5

# %%
# Import the packages that we will be using for the tutorial
import numpy as np # for sampling for the distributions
import matplotlib.pyplot as plt # for basic plotting 
import seaborn as sns; sns.set() # for plotting of the histograms

# Recreate the simulations from the video 
mean_uofm = 155
sd_uofm = 5
mean_gym = 185 
sd_gym = 5 
gymperc = .3
totalPopSize = 40000

# Create the two subgroups
uofm_students = np.random.normal(mean_uofm, sd_uofm, int(totalPopSize * (1 - gymperc)))
students_at_gym = np.random.normal(mean_gym, sd_gym, int(totalPopSize * (gymperc)))

# Create the population from the subgroups
population = np.append(uofm_students, students_at_gym)

# Set up the figure for plotting
plt.figure(figsize=(10,12))

# Plot the UofM students only
plt.subplot(3,1,1)
sns.distplot(uofm_students)
plt.title("UofM Students Only")
plt.xlim([140,200])

# Plot the Gym Goers only
plt.subplot(3,1,2)
sns.distplot(students_at_gym)
plt.title("Gym Goers Only")
plt.xlim([140,200])

# Plot both groups together
plt.subplot(3,1,3)
sns.distplot(population)
plt.title("Full Population of UofM Students")
plt.axvline(x = np.mean(population))
plt.xlim([140,200])

plt.show()
# Out:
# E:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...
